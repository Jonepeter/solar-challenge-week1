# %% [markdown]
# # Solar Data Discovery

# %%
# Import Required Libraries
import os 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy as stat

# %%
# Reading DataSets 
benin_data = pd.read_csv('data/benin-malanaville.csv')
